# %% [markdown]
# #### 1. Basic Input/Output
# ##### Problem: Write a program that takes your name, age, and university name as input and prints them in a formatted sentence.

# %%
name = input("Enter your name: ")
age = int(input("Enter your age: "))
uni = input("Enter University: ")

print(f"I am {name}, {age} years old, studying at {uni}.")
