# %% [markdown]
# Q. find() vs index()

# %%
faculty_name =["Dr V Maths","Dr D Maths","Dr D Maths","Md k SS","HH k Maths"]

# %%
for each in faculty_name:
     if (each.startswith("Dr")!=True) and (each.endswith("Maths")==True):
        print(each)
# Out:
# HH k Maths

# %%
bool(0.2)
# Out:
# True

# %% [markdown]
# Q. a= + number upto 4 digit in reverse order

# %%
v=14322
copy_of_v=14322
while copy_of_v >0:
    print(copy_of_v%10)
    copy_of_v=copy_of_v//10
# Out:
# 2
# 2
# 3
# 4
# 1

# %% [markdown]
# amrstom no. and palindrome
