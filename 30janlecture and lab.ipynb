# %% [markdown]
# ### boolean false == 0
#
# ### boolean true is other than zero

# %%
i =[1,2,3,4,5]
for item in i:
    print(item)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
i=10
while i >0:
    print(i)
    i-=2
# Out:
# 10
# 8
# 6
# 4
# 2

# %%
for item in range(0,5):
    print(item)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for item in range(0,100,3):
    print(item)
# Out:
# 0
# 3
# 6
# 9
# 12
# 15
# 18
# 21
# 24
# 27
# 30
# 33
# 36
# 39
# 42
# 45
# 48
# 51
# 54
# 57
# 60
# 63
# 66
# 69
# 72
# 75
# 78
# 81
# 84
# 87
# 90
# 93
# 96
# 99

# %% [markdown]
# #### In a list of no. find prime numbers and replace with 0

# %%
l=["E","P","E","P"]
for item in l:
    print(item)
# Out:
# E
# P
# E
# P

# %%
for indx,item, in enumerate(l):
    print(item,indx)
    if item =="P":
        l[indx]=0
# Out:
# E 0
# P 1
# E 2
# P 3

# %%
print(l)
# Out:
# ['E', 0, 'E', 0]

# %% [markdown]
# ##### In a list of number find even numbers and replace with 0.

# %%
l=[2,3,4,5,6,7,8,9,10]

# %%
for indx, item in enumerate(l):
    print("the item value is:",item)
    print("the indx is:",indx)
# Out:
# the item value is: 2
# the indx is: 0
# the item value is: 3
# the indx is: 1
# the item value is: 4
# the indx is: 2
# the item value is: 5
# the indx is: 3
# the item value is: 6
# the indx is: 4
# the item value is: 7
# the indx is: 5
# the item value is: 8
# the indx is: 6
# the item value is: 9
# the indx is: 7
# the item value is: 10
# the indx is: 8

# %%
grade=[20,30,12,12,14,14]
names=["v","g","h","i","j","k"]

# %%
for grade, names in zip(grade,names):
    print(grade,names)
# Out:
# 20 v
# 30 g
# 12 h
# 12 i
# 14 j
# 14 k

# %%
l=[1,2,3,4,5,6,7,8,10,11,12]
len(l)
# Out:
# 11

# %%
for item in range(len(l)-1):
    if l[item]-l[item]==1:
        print("the list is natural")
        break
else:
    print("the list is not natural")
# Out:
# the list is not natural
