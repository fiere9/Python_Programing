# %%
type(type(7))
# Out:
# type

# %%
8
# Out:
# 8

# %%
class bca()
    function vss(
        function sfyusqd()
        
    )
# Out:
#   Cell In[12], line 1
#     class bca()
#                ^
# SyntaxError: expected ':'

# %%
v = bca()

# %%
type(True)
# Out:
# bool

# %%
v=7
type(v)
# Out:
# int

# %% [markdown]
# Q. please explain in simple pseudo code how upper  function is not a function method of str?

# %% [markdown]
# super class type ()
#
#       class str()
#
#            function upper

# %% [markdown]
# Q. .class builtin()
#
#     function length()  etc.
#
#     class str()
#
#
# ######   there are many function in it to call in str class we have to do

# %% [markdown]
# class str(builtin)
#
# ###### now we can acess function in str class

# %%
import numpy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 import numpy
#
# ModuleNotFoundError: No module named 'numpy'

# %%
import pandas
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 import pandas
#
# ModuleNotFoundError: No module named 'pandas'

# %%
upper("python"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 print(upper("python"))
#
# NameError: name 'upper' is not defined

# %%
len("python")
# Out:
# 6

# %%
print(type(len("python")))

# %%
l=[a,b,b,f]

# %%
a="python"
a.lower()
