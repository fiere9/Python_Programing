# %% [markdown]
# ## Chapter 1 : Getting started  with python

# %% [markdown]
# #### What is python?

# %% [markdown]
# Python is an interpreted, high-level, general-purpose programming language characterized by an emphasis on code readability and a syntax that allows programmers to express concepts in fewer lines of code than might be possible in languages such as C++ or Java.

# %% [markdown]
# ### What is interactive programming in python?

# %% [markdown]
# When we can run a programing direly from terminal , and the output is instant. We dont need a helper command to run the script.

# %% [markdown]
# ### What is script programming in python?

# %% [markdown]
# When we submitt the script to the compiler using a helper command. In the case of python the terminal command is "python - file name"

# %% [markdown]
# #### Intreactive Python in Jupyter

# %%
a=23
b=46
print("product of a and b:")
print(a*b)
# Out:
# product of a and b:
# 1058

# %% [markdown]
# #### Script mode in Jupyter

# %%
# !python first.py
# Out:
# the sum of a and b: 121

# %% [markdown]
# ### Dynamic Types of Python

# %% [markdown]
# ###### Python as a script or language is what " Dynamically Typed", meaning the varriable are declared during runtime and there dataype is not explicilty specified.

# %%
a=30
a="fakre"
a[1]
# Out:
# 'a'

# %%
a[1]="r"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 a[1]="r"
#
# TypeError: 'str' object does not support item assignment

# %%
a=34
print(type(a))
b=87/3
print(type(b))
c="alam"
print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %% [markdown]
# ### What is the command to check the data type ?

# %% [markdown]
# ###### type(): command is used to check the data type of the current value

# %% [markdown]
# ### What are immutable datatypes ?

# %% [markdown]
# ###### The data types where values cannot be changed once assigned.
#
# ###### Immutable Data Types
#
# ###### 1  Integer (int)
#
# ###### 2  Floating Point (float)
#
# ###### 3  boolean (bool)
#
# ###### 4  string (str)
#
# ###### 5  frozenset
#
# ###### 6  Tuples

# %%
a="abcd"
print(a)
a="a8cd"
print(a)
# Out:
# abcd
# a8cd

# %% [markdown]
# ### What is Tuple ?

# %%
a=(2,3)
print(a[1])
print(type(a))
# Out:
# 3
# <class 'tuple'>
